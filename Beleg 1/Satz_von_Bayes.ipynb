# %%
bk=0.82
ek=0.22
gk=0.09

b=0.018
e=0.105
g=1-b-e
print("y=",g)
print("x=",1-bk)

pk=b*bk+e*ek+g*gk
pb=b
pkb=bk
pbk=(pkb*pb)/pk
print("P(B|K)=",pbk)

pe=e
pke=ek
pek=(pke*pe)/pk
print("P(E|K)=",pek)

pg=g
pkg=gk
pgk=(pkg*pg)/pk
print("P(G|K)=",pgk)
# Out:
# y= 0.877
# x= 0.18000000000000005
# P(B|K)= 0.12638068327767787
# P(E|K)= 0.19779090675571537
# P(G|K)= 0.6758284099666068

# %%
p1=936
p2=1333
p3=1006
p4=1420

r1=0.06
r2=0.06
r3=0.05
r4=0.025

a_ges=p1*r1+p2*r2+p3*r3+p4*r4

print("Ausschuss je Tag=",a_ges)

a1=p1*r1
a2=p2*r2
a3=p3*r3
a4=p4*r4

print("P1 liegt bei=",a1/a_ges)
print("P2 liegt bei=",a2/a_ges)
print("P3 liegt bei=",a3/a_ges)
print("P4 liegt bei=",a4/a_ges)
# Out:
# Ausschuss je Tag= 221.94
# P1 liegt bei= 0.2530413625304136
# P2 liegt bei= 0.36036766693701
# P3 liegt bei= 0.2266378300441561
# P4 liegt bei= 0.1599531404884203
